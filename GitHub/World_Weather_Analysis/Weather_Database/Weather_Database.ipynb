# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import json
import requests

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low =-90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low =-180.000, high = 180.000, size = 2000)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 756

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Date": city_date})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | bambanglipuro
# Processing Record 3 of Set 1 | ostrovnoy
# Processing Record 4 of Set 1 | vao
# Processing Record 5 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | prince rupert
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 13 of Set 1 | rocha
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | hasaki
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | jacqueville
# Processing Record 23 of Set 1 | ilulissat
# Processing Record 24 of Set 1 | najran
# Processing Record 25 of Set 1 | falealupo
# City not found. Skipping...
# Processing Record 26 of Set 1 | balti
# Processing Record 27 of Set 1 | kieta
# Processing Record 28 of Set 1 | birao
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | upernavik
# Processing Record 32 of Set 1 | qaqortoq
# Processing Record 33 of Set 1 | kalaleh
# Processing Record 34 of Set 1 | pontianak
# Processing Record 35 of Set 1 | mugla
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | maragogi
# Processing Record 38 of Set 1 | paraiso
# Processing Record 39 of Set 1 | merritt island
# Processing Record 40 of Set 1 | eureka
# Processing Record 41 of Set 1 | severo-kurilsk
# Processing Record 42 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 1 | manaure
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | faanui
# Processing Record 46 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | villa carlos paz
# Processing Record 50 of Set 1 | elko
# Processing Record 1 of Set 2 | hithadhoo
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | huangmei
# Processing Record 5 of Set 2 | vestmannaeyjar
# Processing Record 6 of Set 2 | noumea
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | christchurch
# Processing Record 9 of Set 2 | carauari
# Processing Record 10 of Set 2 | baykit
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | putina
# Processing Record 13 of Set 2 | kaitangata
# Processing Record 14 of Set 2 | maldonado
# Processing Record 15 of Set 2 | inta
# Processing Record 16 of Set 2 | puerto del rosario
# Processing Record 17 of Set 2 | portland
# Processing Record 18 of Set 2 | pljevlja
# Processing Record 19 of Set 2 | ribeira grande
# Processing Record 20 of Set 2 | lodja
# Processing Record 21 of Set 2 | sorong
# Processing Record 22 of Set 2 | mount isa
# Processing Record 23 of Set 2 | armidale
# Processing Record 24 of Set 2 | tuktoyaktuk
# Processing Record 25 of Set 2 | zhezkazgan
# Processing Record 26 of Set 2 | bolgatanga
# Processing Record 27 of Set 2 | jijiga
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | te horo
# Processing Record 31 of Set 2 | vaini
# Processing Record 32 of Set 2 | atar
# Processing Record 33 of Set 2 | tenenkou
# Processing Record 34 of Set 2 | khatanga
# Processing Record 35 of Set 2 | coquimbo
# Processing Record 36 of Set 2 | nikolskoye
# Processing Record 37 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 2 | les cayes
# Processing Record 39 of Set 2 | calabar
# Processing Record 40 of Set 2 | roebourne
# Processing Record 41 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 2 | evensk
# Processing Record 43 of Set 2 | effingham
# Processing Record 44 of Set 2 | carberry
# Processing Record 45 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 2 | maniitsoq
# Processing Record 47 of Set 2 | talnakh
# Processing Record 48 of Set 2 | lebu
# Processing Record 49 of Set 2 | morondava
# Processing Record 50 of Set 2 | busselton
# Processing Record 1 of Set 3 | yellowknife
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | kahului
# Processing Record 4 of Set 3 | rodos
# Processing Record 5 of Set 3 | yanam
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | balurghat
# Processing Record 8 of Set 3 | baie-comeau
# Processing Record 9 of Set 3 | gillingham
# Processing Record 10 of Set 3 | mto wa mbu
# Processing Record 11 of Set 3 | namtsy
# Processing Record 12 of Set 3 | hambantota
# Processing Record 13 of Set 3 | kathmandu
# Processing Record 14 of Set 3 | den helder
# Processing Record 15 of Set 3 | jinchang
# Processing Record 16 of Set 3 | ozernovskiy
# Processing Record 17 of Set 3 | saskylakh
# Processing Record 18 of Set 3 | port lincoln
# Processing Record 19 of Set 3 | namibe
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | qaanaaq
# Processing Record 22 of Set 3 | alexandria
# Processing Record 23 of Set 3 | coruripe
# Processing Record 24 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 3 | jamestown
# Processing Record 26 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 27 of Set 3 | los llanos de aridane
# Processing Record 28 of Set 3 | victoria
# Processing Record 29 of Set 3 | kropotkin
# Processing Record 30 of Set 3 | mar del plata
# Processing Record 31 of Set 3 | iqaluit
# Processing Record 32 of Set 3 | balkanabat
# Processing Record 33 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | rudnya
# Processing Record 36 of Set 3 | chipiona
# Processing Record 37 of Set 3 | broken hill
# Processing Record 38 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 3 | marang
# Processing Record 40 of Set 3 | souillac
# Processing Record 41 of Set 3 | bethanien
# Processing Record 42 of Set 3 | lavrentiya
# Processing Record 43 of Set 3 | cockburn town
# Processing Record 44 of Set 3 | one hundred mile house
# City not found. Skipping...
# Processing Record 45 of Set 3 | luderitz
# Processing Record 46 of Set 3 | luganville
# Processing Record 47 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 48 of Set 3 | sabang
# Processing Record 49 of Set 3 | cap-aux-meules
# Processing Record 50 of Set 3 | mayumba
# Processing Record 1 of Set 4 | camopi
# Processing Record 2 of Set 4 | kutulik
# Processing Record 3 of Set 4 | mabaruma
# Processing Record 4 of Set 4 | saint-philippe
# Processing Record 5 of Set 4 | champerico
# Processing Record 6 of Set 4 | agadez
# Processing Record 7 of Set 4 | kendari
# Processing Record 8 of Set 4 | osmena
# Processing Record 9 of Set 4 | kuusamo
# Processing Record 10 of Set 4 | sapouy
# Processing Record 11 of Set 4 | chara
# Processing Record 12 of Set 4 | beloha
# Processing Record 13 of Set 4 | yaan
# Processing Record 14 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 4 | torbay
# Processing Record 16 of Set 4 | vardo
# Processing Record 17 of Set 4 | kitimat
# Processing Record 18 of Set 4 | lazaro cardenas
# Processing Record 19 of Set 4 | altamira
# Processing Record 20 of Set 4 | solanea
# Processing Record 21 of Set 4 | chuy
# Processing Record 22 of Set 4 | mehamn
# Processing Record 23 of Set 4 | watsa
# Processing Record 24 of Set 4 | holland
# Processing Record 25 of Set 4 | sao filipe
# Processing Record 26 of Set 4 | makueni
# Processing Record 27 of Set 4 | cabo san lucas
# Processing Record 28 of Set 4 | cap malheureux
# Processing Record 29 of Set 4 | sambava
# Processing Record 30 of Set 4 | ponta do sol
# Processing Record 31 of Set 4 | san cristobal
# Processing Record 32 of Set 4 | myitkyina
# Processing Record 33 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 4 | airai
# Processing Record 35 of Set 4 | solnechnyy
# Processing Record 36 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 4 | taga
# Processing Record 38 of Set 4 | pisco
# Processing Record 39 of Set 4 | cidreira
# Processing Record 40 of Set 4 | sinnamary
# Processing Record 41 of Set 4 | saint-leu
# Processing Record 42 of Set 4 | molteno
# Processing Record 43 of Set 4 | marsaxlokk
# Processing Record 44 of Set 4 | moron
# Processing Record 45 of Set 4 | puerto escondido
# Processing Record 46 of Set 4 | tasiilaq
# Processing Record 47 of Set 4 | norman wells
# Processing Record 48 of Set 4 | tual
# Processing Record 49 of Set 4 | nelson bay
# Processing Record 50 of Set 4 | sayansk
# Processing Record 1 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 5 | inirida
# Processing Record 3 of Set 5 | sao joao da barra
# Processing Record 4 of Set 5 | winslow
# Processing Record 5 of Set 5 | chokurdakh
# Processing Record 6 of Set 5 | flinders
# Processing Record 7 of Set 5 | takestan
# Processing Record 8 of Set 5 | tateyama
# Processing Record 9 of Set 5 | hualmay
# Processing Record 10 of Set 5 | akure
# Processing Record 11 of Set 5 | hervey bay
# Processing Record 12 of Set 5 | russkaya polyana
# Processing Record 13 of Set 5 | sungurlu
# Processing Record 14 of Set 5 | bilibino
# Processing Record 15 of Set 5 | os
# City not found. Skipping...
# Processing Record 16 of Set 5 | kruisfontein
# Processing Record 17 of Set 5 | dungarpur
# Processing Record 18 of Set 5 | sonoita
# Processing Record 19 of Set 5 | arraial do cabo
# Processing Record 20 of Set 5 | obigarm
# Processing Record 21 of Set 5 | yangambi
# Processing Record 22 of Set 5 | portlethen
# Processing Record 23 of Set 5 | bam
# Processing Record 24 of Set 5 | iracoubo
# Processing Record 25 of Set 5 | mahebourg
# Processing Record 26 of Set 5 | nantucket
# Processing Record 27 of Set 5 | santa isabel do rio negro
# Processing Record 28 of Set 5 | samarai
# Processing Record 29 of Set 5 | port hardy
# Processing Record 30 of Set 5 | kununurra
# Processing Record 31 of Set 5 | sao felix do xingu
# Processing Record 32 of Set 5 | norden
# Processing Record 33 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 5 | ures
# Processing Record 35 of Set 5 | saint george
# Processing Record 36 of Set 5 | manicore
# Processing Record 37 of Set 5 | date
# Processing Record 38 of Set 5 | tautira
# Processing Record 39 of Set 5 | kantunilkin
# Processing Record 40 of Set 5 | jacareacanga
# Processing Record 41 of Set 5 | the valley
# Processing Record 42 of Set 5 | sabla
# Processing Record 43 of Set 5 | riyadh
# Processing Record 44 of Set 5 | fortuna
# Processing Record 45 of Set 5 | zhigansk
# Processing Record 46 of Set 5 | innellan
# Processing Record 47 of Set 5 | porvoo
# Processing Record 48 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 5 | tiksi
# Processing Record 50 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 6 | zhob
# Processing Record 2 of Set 6 | dikson
# Processing Record 3 of Set 6 | guerrero negro
# Processing Record 4 of Set 6 | aanekoski
# Processing Record 5 of Set 6 | iskateley
# Processing Record 6 of Set 6 | saldanha
# Processing Record 7 of Set 6 | salme
# Processing Record 8 of Set 6 | gazojak
# Processing Record 9 of Set 6 | beyneu
# Processing Record 10 of Set 6 | rundu
# Processing Record 11 of Set 6 | college
# Processing Record 12 of Set 6 | wollongong
# Processing Record 13 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 14 of Set 6 | coulihaut
# City not found. Skipping...
# Processing Record 15 of Set 6 | mangulile
# Processing Record 16 of Set 6 | pangnirtung
# Processing Record 17 of Set 6 | verkhoyansk
# Processing Record 18 of Set 6 | nunchia
# Processing Record 19 of Set 6 | lasa
# Processing Record 20 of Set 6 | kilindoni
# Processing Record 21 of Set 6 | kitakata
# Processing Record 22 of Set 6 | odweyne
# Processing Record 23 of Set 6 | show low
# Processing Record 24 of Set 6 | lata
# Processing Record 25 of Set 6 | andselv
# City not found. Skipping...
# Processing Record 26 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 27 of Set 6 | grindavik
# Processing Record 28 of Set 6 | narsaq
# Processing Record 29 of Set 6 | pacific grove
# Processing Record 30 of Set 6 | faya
# Processing Record 31 of Set 6 | codrington
# Processing Record 32 of Set 6 | pyaozerskiy
# Processing Record 33 of Set 6 | ukiah
# Processing Record 34 of Set 6 | nizhnevartovsk
# Processing Record 35 of Set 6 | birjand
# Processing Record 36 of Set 6 | sarkand
# Processing Record 37 of Set 6 | male
# Processing Record 38 of Set 6 | laguna
# Processing Record 39 of Set 6 | wanaka
# Processing Record 40 of Set 6 | churapcha
# Processing Record 41 of Set 6 | henties bay
# Processing Record 42 of Set 6 | wanning
# Processing Record 43 of Set 6 | itapuranga
# Processing Record 44 of Set 6 | lufilufi
# Processing Record 45 of Set 6 | bellavista
# Processing Record 46 of Set 6 | nishihara
# Processing Record 47 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 49 of Set 6 | beringovskiy
# Processing Record 50 of Set 6 | dabou
# Processing Record 1 of Set 7 | esperance
# Processing Record 2 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 7 | ahumada
# City not found. Skipping...
# Processing Record 4 of Set 7 | galle
# Processing Record 5 of Set 7 | yumen
# Processing Record 6 of Set 7 | sitka
# Processing Record 7 of Set 7 | wajima
# Processing Record 8 of Set 7 | srednekolymsk
# Processing Record 9 of Set 7 | nago
# Processing Record 10 of Set 7 | ossora
# Processing Record 11 of Set 7 | karacakoy
# Processing Record 12 of Set 7 | stokmarknes
# Processing Record 13 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 14 of Set 7 | salina cruz
# Processing Record 15 of Set 7 | boguchany
# Processing Record 16 of Set 7 | morant bay
# Processing Record 17 of Set 7 | mizdah
# Processing Record 18 of Set 7 | shaowu
# Processing Record 19 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 20 of Set 7 | freeport
# Processing Record 21 of Set 7 | bubaque
# Processing Record 22 of Set 7 | camacha
# Processing Record 23 of Set 7 | prado
# Processing Record 24 of Set 7 | aksarka
# Processing Record 25 of Set 7 | susanville
# Processing Record 26 of Set 7 | klaksvik
# Processing Record 27 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 28 of Set 7 | khasan
# Processing Record 29 of Set 7 | la paz centro
# Processing Record 30 of Set 7 | takhli
# Processing Record 31 of Set 7 | nome
# Processing Record 32 of Set 7 | lorengau
# Processing Record 33 of Set 7 | namatanai
# Processing Record 34 of Set 7 | jimani
# Processing Record 35 of Set 7 | tandil
# Processing Record 36 of Set 7 | bambous virieux
# Processing Record 37 of Set 7 | jiazi
# Processing Record 38 of Set 7 | kouango
# Processing Record 39 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 7 | aykhal
# Processing Record 41 of Set 7 | isangel
# Processing Record 42 of Set 7 | sorland
# Processing Record 43 of Set 7 | dhidhdhoo
# Processing Record 44 of Set 7 | menongue
# Processing Record 45 of Set 7 | magadan
# Processing Record 46 of Set 7 | te anau
# Processing Record 47 of Set 7 | nanortalik
# Processing Record 48 of Set 7 | ughelli
# Processing Record 49 of Set 7 | agucadoura
# Processing Record 50 of Set 7 | pringsewu
# Processing Record 1 of Set 8 | pochutla
# Processing Record 2 of Set 8 | suzu
# City not found. Skipping...
# Processing Record 3 of Set 8 | samana
# Processing Record 4 of Set 8 | peterhead
# Processing Record 5 of Set 8 | gayny
# Processing Record 6 of Set 8 | srandakan
# Processing Record 7 of Set 8 | kosonsoy
# Processing Record 8 of Set 8 | provideniya
# Processing Record 9 of Set 8 | marawi
# Processing Record 10 of Set 8 | tucuma
# Processing Record 11 of Set 8 | kokstad
# Processing Record 12 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 8 | togur
# Processing Record 14 of Set 8 | marzuq
# Processing Record 15 of Set 8 | odesskoye
# Processing Record 16 of Set 8 | la ronge
# Processing Record 17 of Set 8 | palmital
# Processing Record 18 of Set 8 | tiznit
# Processing Record 19 of Set 8 | luena
# Processing Record 20 of Set 8 | gezing
# Processing Record 21 of Set 8 | poum
# Processing Record 22 of Set 8 | smithers
# Processing Record 23 of Set 8 | tuatapere
# Processing Record 24 of Set 8 | bougouni
# Processing Record 25 of Set 8 | longyearbyen
# Processing Record 26 of Set 8 | emerald
# Processing Record 27 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 28 of Set 8 | mangaratiba
# Processing Record 29 of Set 8 | bengkulu
# Processing Record 30 of Set 8 | buala
# Processing Record 31 of Set 8 | urumqi
# Processing Record 32 of Set 8 | zhangye
# Processing Record 33 of Set 8 | touros
# Processing Record 34 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 35 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 8 | labuhan
# Processing Record 37 of Set 8 | sampit
# Processing Record 38 of Set 8 | berdyuzhye
# City not found. Skipping...
# Processing Record 39 of Set 8 | nalut
# Processing Record 40 of Set 8 | puerto princesa
# Processing Record 41 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 8 | awbari
# Processing Record 43 of Set 8 | tilichiki
# Processing Record 44 of Set 8 | gazimurskiy zavod
# Processing Record 45 of Set 8 | mujiayingzi
# Processing Record 46 of Set 8 | asau
# Processing Record 47 of Set 8 | rakiv lis
# Processing Record 48 of Set 8 | maarianhamina
# Processing Record 49 of Set 8 | barrhead
# Processing Record 50 of Set 8 | phan thiet
# Processing Record 1 of Set 9 | tulsipur
# Processing Record 2 of Set 9 | clyde river
# Processing Record 3 of Set 9 | chopovychi
# Processing Record 4 of Set 9 | jand
# Processing Record 5 of Set 9 | coahuayana
# Processing Record 6 of Set 9 | constitucion
# Processing Record 7 of Set 9 | mach
# Processing Record 8 of Set 9 | mikumi
# Processing Record 9 of Set 9 | taltal
# Processing Record 10 of Set 9 | sioux lookout
# Processing Record 11 of Set 9 | kyrylivka
# Processing Record 12 of Set 9 | port-gentil
# Processing Record 13 of Set 9 | shchelyayur
# City not found. Skipping...
# Processing Record 14 of Set 9 | kilmallock
# Processing Record 15 of Set 9 | tezu
# Processing Record 16 of Set 9 | urucui
# Processing Record 17 of Set 9 | charters towers
# Processing Record 18 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 9 | muyezerskiy
# Processing Record 20 of Set 9 | ibanda
# Processing Record 21 of Set 9 | senanga
# Processing Record 22 of Set 9 | yakeshi
# Processing Record 23 of Set 9 | lethem
# Processing Record 24 of Set 9 | tucurui
# Processing Record 25 of Set 9 | progreso
# Processing Record 26 of Set 9 | ambilobe
# Processing Record 27 of Set 9 | shar
# Processing Record 28 of Set 9 | alta floresta
# Processing Record 29 of Set 9 | rondonopolis
# Processing Record 30 of Set 9 | brae
# Processing Record 31 of Set 9 | bathsheba
# Processing Record 32 of Set 9 | port hedland
# Processing Record 33 of Set 9 | darhan
# Processing Record 34 of Set 9 | poronaysk
# Processing Record 35 of Set 9 | san jeronimo
# Processing Record 36 of Set 9 | botou
# Processing Record 37 of Set 9 | sisimiut
# Processing Record 38 of Set 9 | vila velha
# Processing Record 39 of Set 9 | dunedin
# Processing Record 40 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 9 | salym
# Processing Record 42 of Set 9 | victor harbor
# Processing Record 43 of Set 9 | yerofey pavlovich
# Processing Record 44 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 9 | lompoc
# Processing Record 46 of Set 9 | cermik
# Processing Record 47 of Set 9 | tongren
# Processing Record 48 of Set 9 | plettenberg bay
# Processing Record 49 of Set 9 | vaitape
# Processing Record 50 of Set 9 | baoning
# Processing Record 1 of Set 10 | carballo
# Processing Record 2 of Set 10 | providencia
# Processing Record 3 of Set 10 | alofi
# Processing Record 4 of Set 10 | boralday
# Processing Record 5 of Set 10 | fort nelson
# Processing Record 6 of Set 10 | bose
# Processing Record 7 of Set 10 | balikpapan
# Processing Record 8 of Set 10 | novo oriente
# Processing Record 9 of Set 10 | smolensk
# Processing Record 10 of Set 10 | tecoanapa
# Processing Record 11 of Set 10 | non sang
# Processing Record 12 of Set 10 | takoradi
# Processing Record 13 of Set 10 | egvekinot
# Processing Record 14 of Set 10 | dhone
# Processing Record 15 of Set 10 | hamilton
# Processing Record 16 of Set 10 | hay river
# Processing Record 17 of Set 10 | newport beach
# Processing Record 18 of Set 10 | talaya
# Processing Record 19 of Set 10 | bumba
# Processing Record 20 of Set 10 | kampene
# Processing Record 21 of Set 10 | saint-georges
# Processing Record 22 of Set 10 | katsuura
# Processing Record 23 of Set 10 | harper
# Processing Record 24 of Set 10 | blyznyuky
# Processing Record 25 of Set 10 | coihaique
# Processing Record 26 of Set 10 | orlik
# Processing Record 27 of Set 10 | manzanillo
# Processing Record 28 of Set 10 | benxi
# Processing Record 29 of Set 10 | saint-augustin
# Processing Record 30 of Set 10 | okhotsk
# Processing Record 31 of Set 10 | oktyabrskiy
# Processing Record 32 of Set 10 | dumas
# Processing Record 33 of Set 10 | whitehorse
# Processing Record 34 of Set 10 | calamar
# Processing Record 35 of Set 10 | ovalle
# Processing Record 36 of Set 10 | baoding
# Processing Record 37 of Set 10 | paine
# Processing Record 38 of Set 10 | qiongshan
# Processing Record 39 of Set 10 | marfino
# Processing Record 40 of Set 10 | kavaratti
# Processing Record 41 of Set 10 | cururupu
# Processing Record 42 of Set 10 | gotsu
# Processing Record 43 of Set 10 | havre-saint-pierre
# Processing Record 44 of Set 10 | port augusta
# Processing Record 45 of Set 10 | idlib
# Processing Record 46 of Set 10 | palu
# Processing Record 47 of Set 10 | samfya
# Processing Record 48 of Set 10 | gamba
# Processing Record 49 of Set 10 | lavumisa
# Processing Record 50 of Set 10 | khani
# Processing Record 1 of Set 11 | nouadhibou
# Processing Record 2 of Set 11 | aripuana
# Processing Record 3 of Set 11 | madang
# Processing Record 4 of Set 11 | tete
# Processing Record 5 of Set 11 | batticaloa
# Processing Record 6 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 11 | langsa
# Processing Record 8 of Set 11 | wangdiphodrang
# City not found. Skipping...
# Processing Record 9 of Set 11 | san quintin
# Processing Record 10 of Set 11 | cherskiy
# Processing Record 11 of Set 11 | auki
# Processing Record 12 of Set 11 | ulladulla
# Processing Record 13 of Set 11 | troitsko-pechorsk
# Processing Record 14 of Set 11 | adrar
# Processing Record 15 of Set 11 | tonj
# Processing Record 16 of Set 11 | kalmunai
# Processing Record 17 of Set 11 | udachnyy
# Processing Record 18 of Set 11 | vostok
# Processing Record 19 of Set 11 | pingliang
# Processing Record 20 of Set 11 | bagacay
# Processing Record 21 of Set 11 | mecca
# Processing Record 22 of Set 11 | svetlyy
# Processing Record 23 of Set 11 | chase
# Processing Record 24 of Set 11 | kabanjahe
# Processing Record 25 of Set 11 | marbella
# Processing Record 26 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 27 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 28 of Set 11 | hami
# Processing Record 29 of Set 11 | bao
# Processing Record 30 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 11 | bandarbeyla
# Processing Record 32 of Set 11 | mathathane
# Processing Record 33 of Set 11 | merritt
# Processing Record 34 of Set 11 | waipawa
# Processing Record 35 of Set 11 | salta
# Processing Record 36 of Set 11 | jiaonan
# Processing Record 37 of Set 11 | strezhevoy
# Processing Record 38 of Set 11 | karratha
# Processing Record 39 of Set 11 | saskatoon
# Processing Record 40 of Set 11 | carutapera
# Processing Record 41 of Set 11 | sussex
# Processing Record 42 of Set 11 | afsin
# Processing Record 43 of Set 11 | sola
# Processing Record 44 of Set 11 | markapur
# Processing Record 45 of Set 11 | currais novos
# Processing Record 46 of Set 11 | wukari
# Processing Record 47 of Set 11 | hutchinson
# Processing Record 48 of Set 11 | isfana
# Processing Record 49 of Set 11 | naze
# Processing Record 50 of Set 11 | batagay-alyta
# Processing Record 1 of Set 12 | avera
# Processing Record 2 of Set 12 | sakakah
# Processing Record 3 of Set 12 | awjilah
# Processing Record 4 of Set 12 | fare
# Processing Record 5 of Set 12 | totness
# Processing Record 6 of Set 12 | nata
# Processing Record 7 of Set 12 | jablah
# Processing Record 8 of Set 12 | talara
# Processing Record 9 of Set 12 | dubbo
# Processing Record 10 of Set 12 | port blair
# Processing Record 11 of Set 12 | port macquarie
# Processing Record 12 of Set 12 | anadyr
# Processing Record 13 of Set 12 | tromso
# Processing Record 14 of Set 12 | teguise
# Processing Record 15 of Set 12 | tabory
# Processing Record 16 of Set 12 | aybak
# City not found. Skipping...
# Processing Record 17 of Set 12 | neftcala
# Processing Record 18 of Set 12 | yuncheng
# Processing Record 19 of Set 12 | nuuk
# Processing Record 20 of Set 12 | pakxan
# Processing Record 21 of Set 12 | haines junction
# Processing Record 22 of Set 12 | recea
# Processing Record 23 of Set 12 | atasu
# Processing Record 24 of Set 12 | sept-iles
# Processing Record 25 of Set 12 | ahipara
# Processing Record 26 of Set 12 | trairi
# Processing Record 27 of Set 12 | liverpool
# Processing Record 28 of Set 12 | ankang
# Processing Record 29 of Set 12 | ucluelet
# Processing Record 30 of Set 12 | mahibadhoo
# Processing Record 31 of Set 12 | padang
# Processing Record 32 of Set 12 | pundaguitan
# Processing Record 33 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 34 of Set 12 | kasongo-lunda
# Processing Record 35 of Set 12 | kitui
# Processing Record 36 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 37 of Set 12 | lagoa
# Processing Record 38 of Set 12 | nizwa
# Processing Record 39 of Set 12 | healdsburg
# Processing Record 40 of Set 12 | harrisburg
# Processing Record 41 of Set 12 | singapore
# Processing Record 42 of Set 12 | kurchum
# Processing Record 43 of Set 12 | hammel
# Processing Record 44 of Set 12 | el carrizo
# Processing Record 45 of Set 12 | terrace
# Processing Record 46 of Set 12 | piacabucu
# Processing Record 47 of Set 12 | korla
# Processing Record 48 of Set 12 | oktyabrskoye
# Processing Record 49 of Set 12 | bonavista
# Processing Record 50 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 13 | ballina
# Processing Record 2 of Set 13 | mehran
# Processing Record 3 of Set 13 | palana
# Processing Record 4 of Set 13 | tabulbah
# City not found. Skipping...
# Processing Record 5 of Set 13 | deputatskiy
# Processing Record 6 of Set 13 | quatre cocos
# Processing Record 7 of Set 13 | mogadishu
# Processing Record 8 of Set 13 | aklavik
# Processing Record 9 of Set 13 | el seibo
# Processing Record 10 of Set 13 | dasoguz
# Processing Record 11 of Set 13 | ambon
# Processing Record 12 of Set 13 | kenai
# Processing Record 13 of Set 13 | west sacramento
# Processing Record 14 of Set 13 | bahia honda
# Processing Record 15 of Set 13 | ngunguru
# Processing Record 16 of Set 13 | kavieng
# Processing Record 17 of Set 13 | lapithos
# Processing Record 18 of Set 13 | lexington
# Processing Record 19 of Set 13 | sorgun
# Processing Record 20 of Set 13 | shadrinsk
# Processing Record 21 of Set 13 | sturgis
# Processing Record 22 of Set 13 | sumbawanga
# Processing Record 23 of Set 13 | japura
# Processing Record 24 of Set 13 | san jose de rio tinto
# Processing Record 25 of Set 13 | broome
# Processing Record 26 of Set 13 | ancud
# Processing Record 27 of Set 13 | chiang khong
# Processing Record 28 of Set 13 | sao gabriel da cachoeira
# Processing Record 29 of Set 13 | saint-pierre
# Processing Record 30 of Set 13 | vanimo
# Processing Record 31 of Set 13 | rodrigues alves
# Processing Record 32 of Set 13 | viedma
# Processing Record 33 of Set 13 | okahandja
# Processing Record 34 of Set 13 | goya
# Processing Record 35 of Set 13 | seoul
# Processing Record 36 of Set 13 | surt
# Processing Record 37 of Set 13 | tomatlan
# Processing Record 38 of Set 13 | richards bay
# Processing Record 39 of Set 13 | presidencia roque saenz pena
# Processing Record 40 of Set 13 | olafsvik
# Processing Record 41 of Set 13 | palauig
# Processing Record 42 of Set 13 | dwarka
# Processing Record 43 of Set 13 | margate
# Processing Record 44 of Set 13 | carmen
# Processing Record 45 of Set 13 | gazli
# Processing Record 46 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 13 | tabriz
# Processing Record 48 of Set 13 | maua
# Processing Record 49 of Set 13 | cangucu
# Processing Record 50 of Set 13 | conde
# Processing Record 1 of Set 14 | chitose
# Processing Record 2 of Set 14 | san patricio
# Processing Record 3 of Set 14 | acapulco
# Processing Record 4 of Set 14 | makakilo city
# Processing Record 5 of Set 14 | shingu
# Processing Record 6 of Set 14 | babu
# Processing Record 7 of Set 14 | bartica
# Processing Record 8 of Set 14 | baiyin
# Processing Record 9 of Set 14 | marshall
# Processing Record 10 of Set 14 | san ramon
# Processing Record 11 of Set 14 | ilo
# Processing Record 12 of Set 14 | contai
# Processing Record 13 of Set 14 | kamina
# Processing Record 14 of Set 14 | dinghai
# Processing Record 15 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 16 of Set 14 | tlahualilo
# City not found. Skipping...
# Processing Record 17 of Set 14 | changping
# Processing Record 18 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 14 | kamenka
# Processing Record 20 of Set 14 | tsarychanka
# Processing Record 21 of Set 14 | juneau
# Processing Record 22 of Set 14 | farafangana
# Processing Record 23 of Set 14 | zamora
# Processing Record 24 of Set 14 | pahrump
# Processing Record 25 of Set 14 | lithgow
# Processing Record 26 of Set 14 | leningradskiy
# Processing Record 27 of Set 14 | cabedelo
# Processing Record 28 of Set 14 | mugumu
# Processing Record 29 of Set 14 | itarema
# Processing Record 30 of Set 14 | ibra
# Processing Record 31 of Set 14 | pacifica
# Processing Record 32 of Set 14 | chabahar
# Processing Record 33 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 14 | tiarei
# Processing Record 35 of Set 14 | saint anthony
# Processing Record 36 of Set 14 | george town
# Processing Record 37 of Set 14 | arcata
# Processing Record 38 of Set 14 | caravelas
# Processing Record 39 of Set 14 | tazovskiy
# Processing Record 40 of Set 14 | arlit
# Processing Record 41 of Set 14 | novyy oskol
# Processing Record 42 of Set 14 | alice springs
# Processing Record 43 of Set 14 | jizan
# Processing Record 44 of Set 14 | maridi
# Processing Record 45 of Set 14 | byron bay
# Processing Record 46 of Set 14 | praya
# Processing Record 47 of Set 14 | husavik
# Processing Record 48 of Set 14 | murdochville
# Processing Record 49 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 14 | denpasar
# Processing Record 1 of Set 15 | coalcoman
# City not found. Skipping...
# Processing Record 2 of Set 15 | azangaro
# Processing Record 3 of Set 15 | pandan
# Processing Record 4 of Set 15 | natal
# Processing Record 5 of Set 15 | singaparna
# Processing Record 6 of Set 15 | macas
# Processing Record 7 of Set 15 | harlingen
# Processing Record 8 of Set 15 | riyaq
# City not found. Skipping...
# Processing Record 9 of Set 15 | vammala
# Processing Record 10 of Set 15 | rincon
# Processing Record 11 of Set 15 | koupela
# Processing Record 12 of Set 15 | xinxiang
# Processing Record 13 of Set 15 | ust-nera
# Processing Record 14 of Set 15 | jeremoabo
# Processing Record 15 of Set 15 | qui nhon
# Processing Record 16 of Set 15 | kulhudhuffushi
# Processing Record 17 of Set 15 | causapscal
# Processing Record 18 of Set 15 | marsh harbour
# Processing Record 19 of Set 15 | chengde
# Processing Record 20 of Set 15 | geraldton
# Processing Record 21 of Set 15 | nemuro
# Processing Record 22 of Set 15 | asosa
# Processing Record 23 of Set 15 | aden
# Processing Record 24 of Set 15 | poya
# Processing Record 25 of Set 15 | leh
# Processing Record 26 of Set 15 | gijon
# Processing Record 27 of Set 15 | barwadih
# Processing Record 28 of Set 15 | sherlovaya gora
# Processing Record 29 of Set 15 | jalu
# Processing Record 30 of Set 15 | axim
# Processing Record 31 of Set 15 | dryden
# Processing Record 32 of Set 15 | pionerskiy
# Processing Record 33 of Set 15 | flers
# Processing Record 34 of Set 15 | kloulklubed
# Processing Record 35 of Set 15 | touba
# Processing Record 36 of Set 15 | kampot
# Processing Record 37 of Set 15 | tefe
# Processing Record 38 of Set 15 | mitsamiouli
# Processing Record 39 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 40 of Set 15 | llandrindod wells
# Processing Record 41 of Set 15 | shimoda
# Processing Record 42 of Set 15 | zyryanka
# Processing Record 43 of Set 15 | mitchell
# Processing Record 44 of Set 15 | bud
# Processing Record 45 of Set 15 | huarmey
# Processing Record 46 of Set 15 | floro
# Processing Record 47 of Set 15 | sao francisco de assis
# Processing Record 48 of Set 15 | morki
# Processing Record 49 of Set 15 | tosya
# Processing Record 50 of Set 15 | north bend
# Processing Record 1 of Set 16 | pierre
# Processing Record 2 of Set 16 | pressbaum
# Processing Record 3 of Set 16 | achacachi
# Processing Record 4 of Set 16 | villanueva
# Processing Record 5 of Set 16 | xai-xai
# Processing Record 6 of Set 16 | flin flon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 692

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Bredasdorp      ZA -34.5322   20.0403     61.63        91          60
# 1  Bambanglipuro      ID  -7.9500  110.2833     84.58        68          99
# 2      Ostrovnoy      RU  68.0531   39.5131     38.37        64         100
# 3            Vao      NC -22.6667  167.4833     72.66        75         100
# 4    New Norfolk      AU -42.7826  147.0587     56.91        73          99
# 5         Atuona      PF  -9.8000 -139.0333     77.04        75           3
# 6    East London      ZA -33.0153   27.9116     65.34        94          40
# 7  Prince Rupert      CA  54.3161 -130.3201     50.09        84         100
# 8         Castro      BR -24.7911  -50.0119     58.01        85          25
# 9      Cape Town      ZA -33.9258   18.4232     62.28        83           0
#
#    Wind Speed Current Description                 Date
# 0        6.15       broken clouds  2022-10-24 03:47:07
# 1        8.52     overcast clouds  2022-10-24 03:47:07
# 2       25.01          light rain  2022-10-24 03:42:37
# 3       21.74     overcast clouds  2022-10-24 03:44:59
# 4        1.99     overcast clouds  2022-10-24 03:47:08
# 5       17.45           clear sky  2022-10-24 03:47:08
# 6        3.44    scattered clouds  2022-10-24 03:47:09
# 7       37.98          light rain  2022-10-24 03:47:09
# 8        1.74    scattered clouds  2022-10-24 03:47:09
# 9       11.50           clear sky  2022-10-24 03:46:41

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
# Recreate the DataFrame by using the new column order

reordered_city_data_df = pd.DataFrame(new_column_order)


# Display sample data
reordered_city_data_df
# Out:
#                      0
# 0                 City
# 1              Country
# 2                  Lat
# 3                  Lng
# 4             Max Temp
# 5             Humidity
# 6           Cloudiness
# 7           Wind Speed
# 8  Current Description

# %%
# Display the data types of each column by using the dtypes Pandas function
reordered_city_data_df.dtypes
# Out:
# 0    object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
